# %% [markdown]
# # SafeGuard AI — Model Training & Paper Experiment Notebook
# This notebook provides a reproducible environment for training, evaluating, and visualizing multi-label classification algorithms for the SafeGuard AI research paper.

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.train import train_and_evaluate_models
from src.predict import SafeguardPredictor

# 1. Execute Training & Evaluation Pipeline
model_obj, vectorizer, mlb, summary = train_and_evaluate_models('../data/demo_dataset.csv')

# %% [markdown]
# ## Visualizing Model Metrics

# %%
evals = summary['evaluations']
df_metrics = pd.DataFrame(evals).T
print(df_metrics[['exact_match_accuracy', 'hamming_loss', 'f1_micro', 'f1_macro']])
